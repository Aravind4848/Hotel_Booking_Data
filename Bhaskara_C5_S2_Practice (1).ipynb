# %%
import pandas as pd
from tabulate import tabulate
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data set.
df = pd.read_csv('DS1_C5_S1_EmployeeAttrition_Data_Practice.csv')
df
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 2     37.0       Yes      Travel_Rarely  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %%
# To find the columns
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Seperating the numerical and categorical columns

# Displaying the Numerical columns
Num_col = df.select_dtypes(exclude = 'object')

# Displaying the categorical columns
Cat_col = df.select_dtypes(include = 'object')

# %%
Cat_col
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No                NaN  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
# Filling the missing values of business travel with the mode value i.e., Travel Rarely.
df['BusinessTravel'] = df['BusinessTravel'].fillna('Travel_Rarely')

# Filling the missing department values with the mode value i.e., Research & Development.
df['Department'] = df['Department'].fillna('Research & Development')

# Filling the missing values of the Education field with the mode value i.e., Life Sciences.
df['EducationField'] = df['EducationField'].fillna('Life Sciences')

# Filling the missing values of Gender with the mode value i.e., Male.
df['Gender'] = df['Gender'].fillna('Male')

# Filling the missing values of Gender with the mode value i.e., Male.
df['MaritalStatus'] = df['MaritalStatus'].fillna('Married')

# Filling the missing values of Job Role with the mode value i.e., Sales Executive.
df['JobRole'] = df['JobRole'].fillna('Sales Executive')

# Filling the missing values of Marital Status with the mode value i.e., Married.
df['JobRole'] = df['JobRole'].fillna('Married')

# Filling the missing values of Over18 with the mode value i.e., Y.
df['Over18'] = df['Over18'].fillna('Y')

# %% [markdown]
# # Task 1

# %%
# Displaying Business Travel wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'BusinessTravel', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: This category has the highest number of both leavers and stayers.
# These categories have lower numbers of both leavers and stayers.

# %%
# Displaying Education Field wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'EducationField', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: This suggests that employees with these educational backgrounds are more likely to leave the company.
# This indicates that employees with these educational backgrounds tend to stay with the company more.

# %%
# Displaying Department wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'Department', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: employees in this department are more likely to leave the company.
# employees in these departments tend to stay with the company more.

# %%
# Displaying Environment Satisfaction wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'EnvironmentSatisfaction', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: employees who are more satisfied with their work environment are more likely to leave the company.
# employees who are less satisfied with their work environment tend to stay with the company more.

# %%
# Displaying Gender wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'Gender', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: This suggests that females are more likely to leave the company.
# indicates that males tend to stay with the company more.

# %%
# Displaying Marital Status wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'MaritalStatus', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: This suggests that married employees are more likely to leave the company.
# This indicates that single employees tend to stay with the company more.

# %%
# Displaying OverTime wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'OverTime', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: This suggests that employees who work overtime are more likely to leave the company.
# This indicates that employees who don't work overtime tend to stay with the company more.

# %%
# Displaying Performance Rating wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'PerformanceRating', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: This suggests that employees with a performance rating of 3 are more likely to leave the company.
# indicates that employees with a performance rating of 4 tend to stay with the company more.

# %%
# Displaying Job Satisfaction wise employee attrition using countplot
figure,ax = plt.subplots(1, figsize=(10, 5))
sns.countplot(x = 'JobSatisfaction', hue = 'Attrition', data = df)
plt.show()

# %% [raw]
# # Interpretation: This suggests that employees who are more satisfied with their jobs are more likely to leave the company.
# This indicates that employees who are less satisfied with their jobs tend to stay with the company more.

# %% [markdown]
# # Task 2

# %%
# Displaying the Age group wise attrition using a bar and boxplot chart

figure,ax = plt.subplots(1, 2, figsize=(35, 6))

sns.countplot(x = 'Age', hue = 'Age', ax=ax[0], data = df)
sns.boxplot(x = 'Attrition', y = 'Age', ax=ax[1], data=df)

plt.show()

# %% [raw]
# # Interpretation: The left chart shows the distribution of employees by age.
# It appears that most employees are in their late 20s to early 40s.
# The right chart shows the distribution of employee attrition by age.
# There is no significant difference in attrition rate between different age groups.

# %%
# Displaying the Hourly Rate wise attrition using a bar and boxplot chart

figure,ax = plt.subplots(1, 2, figsize=(35, 6))

sns.countplot(x = 'HourlyRate', hue = 'HourlyRate', ax=ax[0], data = df)
sns.boxplot(x = 'Attrition', y = 'HourlyRate', ax=ax[1], data=df)

plt.show()

# %% [raw]
# # Interpretation: The left chart shows the distribution of employees by age. It appears that most employees are in their late 20s to early 40s.
# The right chart shows the distribution of employee attrition by age. It appears that employees of all ages are equally likely to leave the company. There is no significant difference in attrition rate between different age groups.

# %%
# Displaying the Monthly Income wise attrition using a bar and boxplot chart

figure,ax = plt.subplots(1, 2, figsize=(35, 6))

sns.countplot(x = 'MonthlyIncome', hue = 'MonthlyIncome', ax=ax[0], data = df)
sns.boxplot(x = 'Attrition', y = 'MonthlyIncome', ax=ax[1], data=df)

plt.show()

# %%
# Displaying the Distance From Home wise attrition using a bar and boxplot chart

figure,ax = plt.subplots(1, 2, figsize=(20, 6))

sns.countplot(x = 'DistanceFromHome', hue = 'DistanceFromHome', ax=ax[0], data = df)
sns.boxplot(x = 'Attrition', y = 'DistanceFromHome', ax=ax[1], data=df)

plt.show()

# %% [raw]
# # Interpretation: The left chart shows the distribution of employees by distance from home. Most employees live within 10 miles of their workplace.
# The right chart shows the distribution of distance from home for employees who have left the company (attrition) and those who have stayed. It appears that employees who live farther from their workplace are more likely to leave the company.

# %%
# Displaying the Total Working Years wise attrition using a bar and boxplot chart

figure,ax = plt.subplots(1, 2, figsize=(20, 6))

sns.countplot(x = 'TotalWorkingYears', hue = 'TotalWorkingYears', ax=ax[0], data = df)
sns.boxplot(x = 'Attrition', y = 'TotalWorkingYears', ax=ax[1], data=df)

plt.show()

# %% [raw]
# # Interpretataion: The left chart shows the distribution of employees by total working years. Most employees have been with the company for less than 10 years.
# The right chart shows the distribution of total working years for employees who have left the company (attrition) and those who have stayed.

# %% [markdown]
# # Task 3

# %%
# Employees who travel rarely
df1 = df[df['BusinessTravel'] == 'Travel_Rarely']
df1
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0     41.0       Yes  Travel_Rarely                   Sales                 1
# 2     37.0       Yes  Travel_Rarely  Research & Development                 2
# 4     27.0        No  Travel_Rarely  Research & Development                 2
# 6     59.0        No  Travel_Rarely  Research & Development                 3
# 7     30.0        No  Travel_Rarely  Research & Development                24
# ...    ...       ...            ...                     ...               ...
# 1464  26.0        No  Travel_Rarely                   Sales                 5
# 1465  36.0        No  Travel_Rarely  Research & Development                23
# 1466  39.0        No  Travel_Rarely  Research & Development                 6
# 1467  27.0        No  Travel_Rarely  Research & Development                 4
# 1469  34.0        No  Travel_Rarely  Research & Development                 8
#
# ...

# %%
# Job role wise count of attrited employees who were travelling rarely
figure, ax = plt.subplots(1, figsize=(20, 6))

sns.countplot(x='JobRole', hue='BusinessTravel', data=df1)
plt.show()

# %% [raw]
# # Interpretation: This suggests that these roles might involve less frequent business travel compared to other job roles.
# This indicates that employees in Human Resources might have more frequent business travel compared to other job roles.

# %% [markdown]
# # Task 4

# %%
df2= df[(df['EducationField'] == 'Life Sciences') | (df['EducationField'] == 'Medical')]
df2
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# 5     32.0        No  Travel_Frequently  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No      Travel_Rarely  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %%
# Job role wise employee attrition from Life Sciences and Medical.
figure, ax = plt.subplots(1, figsize = (20, 6))

sns.countplot(x='JobRole', hue = 'Attrition', data=df2)
plt.show()

# %% [raw]
# # Interpretation: Research Scientist and Sales Executive have the highest number of employees who have left the company.
# Human Resources has the lowest number of employees who have left the company.
